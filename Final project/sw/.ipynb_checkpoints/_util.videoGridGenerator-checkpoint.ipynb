# %%
from moviepy.editor import *

clip1 = VideoFileClip("_data/401.mp4").resize(height=120)
clip2 = VideoFileClip("_data/402.mp4").resize(height=120).set_start(0.1)
clip3 = VideoFileClip("_data/403.mp4").resize(height=120).set_start(0.2)
clip4 = VideoFileClip("_data/404.mp4").resize(height=120).set_start(0.3)
clip5 = VideoFileClip("_data/405.mp4").resize(height=120).set_start(0.4)
clip6 = VideoFileClip("_data/406.mp4").resize(height=120).set_start(0.5)
clip7 = VideoFileClip("_data/407.mp4").resize(height=120).set_start(0.6)
clip8 = VideoFileClip("_data/408.mp4").resize(height=120).set_start(0.7)
clip9 = VideoFileClip("_data/401.mp4").resize(height=120).set_start(0.8)
clip10 = VideoFileClip("_data/410.mp4").resize(height=120).set_start(0.9)
clip11 = VideoFileClip("_data/411.mp4").resize(height=120).set_start(1)
clip12 = VideoFileClip("_data/412.mp4").resize(height=120).set_start(1.1)
clip13 = VideoFileClip("_data/413.mp4").resize(height=120).set_start(1.2)
clip14 = VideoFileClip("_data/414.mp4").resize(width=120).set_start(1.3)
blackmask = ColorClip(size=(120,120), color=[0,0,0]).set_duration(60)

final_clip = clips_array([[clip1, clip2, clip3, clip4, clip5],
                          [clip6, clip7, clip8, clip9, clip10],
                          [clip11, clip12, clip13, clip14, blackmask]])
final_clip.resize(width=720).volumex(0).write_videofile("stack_original2.mp4")
# Out:
# chunk:   3%|▎         | 43/1345 [00:00<00:03, 426.14it/s, now=None]
# Moviepy - Building video stack_original2.mp4.
# MoviePy - Writing audio in %s
# chunk:  97%|█████████▋| 1305/1345 [00:04<00:00, 383.59it/s, now=None]WARNING: Logging before flag parsing goes to stderr.
# W0830 03:44:30.811630 140263484094208 warnings.py:99] /usr/local/lib/python3.6/dist-packages/moviepy/audio/io/readers.py:201: UserWarning: Error in file _data/404.mp4, At time t=60.04-60.08 seconds, indices wanted: 98937-99582, but len(buffer)=98938
# index 98938 is out of bounds for axis 0 with size 98938
#   UserWarning)
#
# W0830 03:44:30.825721 140263484094208 warnings.py:99] /usr/local/lib/python3.6/dist-packages/moviepy/audio/io/readers.py:201: UserWarning: Error in file _data/408.mp4, At time t=60.04-60.09 seconds, indices wanted: 98585-98878, but len(buffer)=98586
# index 98586 is out of bounds for axis 0 with size 98586
#   UserWarning)
#
# ...

# %%
from moviepy.editor import *

clip1 = VideoFileClip("_padded_output/401.mp4").resize(height=120)
clip2 = VideoFileClip("_padded_output/401_1.mp4").resize(height=120)#.set_start(0.1)
clip3 = VideoFileClip("_padded_output/401_2.mp4").resize(height=120)#.set_start(0.2)
clip4 = VideoFileClip("_padded_output/401_3.mp4").resize(height=120)#.set_start(0.3)
clip5 = VideoFileClip("_padded_output/401_4.mp4").resize(height=120)#.set_start(0.4)
clip6 = VideoFileClip("_padded_output/401_5.mp4").resize(height=120)#.set_start(0.5)
clip7 = VideoFileClip("_padded_output/401_6.mp4").resize(height=120)#.set_start(0.6)
clip8 = VideoFileClip("_padded_output/401_7.mp4").resize(height=120)#.set_start(0.7)
clip9 = VideoFileClip("_padded_output/401_8.mp4").resize(height=120)#.set_start(0.8)
clip10 = VideoFileClip("_padded_output/401_9.mp4").resize(height=120)#.set_start(0.9)
clip11 = VideoFileClip("_padded_output/401_10.mp4").resize(height=120)#.set_start(1)
clip12 = VideoFileClip("_padded_output/401_11.mp4").resize(height=120)#.set_start(1.1)
clip13 = VideoFileClip("_padded_output/401_12.mp4").resize(height=120)#.set_start(1.2)
clip14 = VideoFileClip("_padded_output/401_13.mp4").resize(height=120)#.set_start(1.3)
blackmask = ColorClip(size=(120,120), color=[0,0,0]).set_duration(60)

final_clip = clips_array([[clip1, clip2, clip3, clip4, clip5],
                          [clip6, clip7, clip8, clip9, clip10],
                          [clip11, clip12, clip13, clip14, blackmask]])
final_clip.resize(width=720).volumex(0).write_videofile("stack_final.mp4")
# Out:
# chunk:   1%|          | 33/2885 [00:00<00:08, 327.02it/s, now=None]
# Moviepy - Building video stack_final.mp4.
# MoviePy - Writing audio in %s
# t:   0%|          | 8/3925 [00:00<00:53, 72.96it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video stack_final.mp4
# t: 100%|█████████▉| 3922/3925 [01:06<00:00, 64.02it/s, now=None]W0830 03:46:22.609191 140263484094208 warnings.py:99] /usr/local/lib/python3.6/dist-packages/moviepy/video/io/ffmpeg_reader.py:130: UserWarning: Warning: in file _padded_output/401.mp4, 691200 bytes wanted but 0 bytes read,at frame 3923/3925, at time 130.77/130.82 sec. Using the last valid frame instead.
#   UserWarning)
#
# W0830 03:46:22.611707 140263484094208 warnings.py:99] /usr/local/lib/python3.6/dist-packages/moviepy/video/io/ffmpeg_reader.py:130: UserWarning: Warning: in file _padded_output/401_1.mp4, 691200 bytes wanted but 0 bytes read,at frame 3923/3925, at time 130.77/130.82 sec. Using the last valid frame instead.
#   UserWarning)
#
# ...
