# %%
from moviepy.editor import *

# audio_master = AudioFileClip("_assets/Audio_Full.mp3")

clip1 = VideoFileClip("_data/401.mp4").resize(height=120)#.set_audio(audio_master)
clip2 = VideoFileClip("_data/402.mp4").resize(height=120).set_start(0.1)
clip3 = VideoFileClip("_data/403.mp4").resize(height=120).set_start(0.2)
clip4 = VideoFileClip("_data/404.mp4").resize(height=120).set_start(0.3)
clip5 = VideoFileClip("_data/405.mp4").resize(height=120).set_start(0.4)
clip6 = VideoFileClip("_data/406.mp4").resize(height=120).set_start(0.5)
clip7 = VideoFileClip("_data/407.mp4").resize(height=120).set_start(0.6)
clip8 = VideoFileClip("_data/408.mp4").resize(height=120).set_start(0.7)
clip9 = VideoFileClip("_data/401.mp4").resize(height=120).set_start(0.8)
clip10 = VideoFileClip("_data/410.mp4").resize(height=120).set_start(0.9)
clip11 = VideoFileClip("_data/411.mp4").resize(height=120).set_start(1)
clip12 = VideoFileClip("_data/412.mp4").resize(height=120).set_start(1.1)
clip13 = VideoFileClip("_data/413.mp4").resize(height=120).set_start(1.2)
clip14 = VideoFileClip("_data/414.mp4").resize(width=120).set_start(1.3)
blackmask = ColorClip(size=(120,120), color=[0,0,0]).set_duration(60)

final_clip = clips_array([[clip1, clip2, clip3, clip4, clip5],
                          [clip6, clip7, clip8, clip9, clip10],
                          [clip11, clip12, clip13, clip14, blackmask]])
final_clip.resize(width=720).volumex(0).write_videofile("stack_original2.mp4")
# Out:
#
# chunk:  47%|████▋     | 630/1345 [04:06<00:02, 281.21it/s, now=None]
#
# ...
# chunk:  21%|██        | 597/2888 [00:14<00:08, 268.04it/s, now=None]
#
# chunk:   0%|          | 0/1345 [00:00<?, ?it/s, now=None]
#
# chunk:   3%|▎         | 43/1345 [00:00<00:03, 421.02it/s, now=None]
# Moviepy - Building video stack_original2.mp4.
# MoviePy - Writing audio in %s
# chunk:   6%|▌         | 76/1345 [00:00<00:03, 388.72it/s, now=None]
#
# chunk:   8%|▊         | 107/1345 [00:00<00:03, 359.01it/s, now=None]
#
# chunk:  10%|▉         | 130/1345 [00:00<00:04, 300.34it/s, now=None]
#
# chunk:  12%|█▏        | 159/1345 [00:00<00:03, 297.00it/s, now=None]
#
# chunk:  14%|█▎        | 184/1345 [00:00<00:04, 279.17it/s, now=None]
#
# chunk:  16%|█▌        | 214/1345 [00:00<00:03, 282.88it/s, now=None]
#
# chunk:  18%|█▊        | 240/1345 [00:00<00:04, 274.31it/s, now=None]
#
# chunk:  20%|█▉        | 268/1345 [00:00<00:03, 275.48it/s, now=None]
#
# ...

# %%
from moviepy.editor import *

audio_master = AudioFileClip("_assets/Audio_Full.mp3")

clip1 = VideoFileClip("_data/401.mp4").resize(height=120).set_audio(audio_master)
clip1 = VideoFileClip("_padded_output/401.mp4").resize(height=120).volumex(0)
clip2 = VideoFileClip("_padded_output/401_1.mp4").resize(height=120).volumex(0)
clip3 = VideoFileClip("_padded_output/401_2.mp4").resize(height=120).volumex(0)
clip4 = VideoFileClip("_padded_output/401_3.mp4").resize(height=120).volumex(0)
clip5 = VideoFileClip("_padded_output/401_4.mp4").resize(height=120).volumex(0)
clip6 = VideoFileClip("_padded_output/401_5.mp4").resize(height=120).volumex(0)
clip7 = VideoFileClip("_padded_output/401_6.mp4").resize(height=120).volumex(0)
clip8 = VideoFileClip("_padded_output/401_7.mp4").resize(height=120).volumex(0)
clip9 = VideoFileClip("_padded_output/401_8.mp4").resize(height=120).volumex(0)
clip10 = VideoFileClip("_padded_output/401_9.mp4").resize(height=120).volumex(0)
clip11 = VideoFileClip("_padded_output/401_10.mp4").resize(height=120).volumex(0)
clip12 = VideoFileClip("_padded_output/401_11.mp4").resize(height=120).volumex(0)
clip13 = VideoFileClip("_padded_output/401_12.mp4").resize(height=120).volumex(0)
clip14 = VideoFileClip("_padded_output/401_13.mp4").resize(height=120).volumex(0)
blackmask = ColorClip(size=(120,120), color=[0,0,0]).set_duration(60)

final_clip = clips_array([[clip1, clip2, clip3, clip4, clip5],
                          [clip6, clip7, clip8, clip9, clip10],
                          [clip11, clip12, clip13, clip14, blackmask]])
final_clip.resize(width=720).write_videofile("stack_final.mp4")
# Out:
#
#
#
# chunk:  47%|████▋     | 630/1345 [04:35<00:02, 281.21it/s, now=None]
#
# t:  10%|▉         | 174/1830 [00:25<00:34, 47.54it/s, now=None]
#
#
#
# chunk:  47%|████▋     | 630/1345 [04:35<00:02, 281.21it/s, now=None]
#
# t:  10%|▉         | 174/1830 [00:25<00:34, 47.54it/s, now=None]
#
#
# chunk:   0%|          | 0/2885 [00:00<?, ?it/s, now=None]
#
#
# chunk:   1%|          | 33/2885 [00:00<00:08, 324.24it/s, now=None]
# Moviepy - Building video stack_final.mp4.
# MoviePy - Writing audio in %s
# chunk:   2%|▏         | 68/2885 [00:00<00:08, 329.75it/s, now=None]
#
#
# chunk:   4%|▎         | 102/2885 [00:00<00:09, 284.52it/s, now=None]
#
#
# chunk:   5%|▍         | 138/2885 [00:00<00:09, 302.20it/s, now=None]
#
#
# chunk:   6%|▌         | 162/2885 [00:00<00:10, 259.64it/s, now=None]
#
#
# chunk:   7%|▋         | 198/2885 [00:00<00:09, 281.44it/s, now=None]
#
#
# chunk:   8%|▊         | 225/2885 [00:00<00:10, 253.70it/s, now=None]
#
#
# ...
